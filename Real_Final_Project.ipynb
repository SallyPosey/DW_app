# %% [markdown]
# <a href="https://colab.research.google.com/github/SallyPosey/DW_app/blob/main/Real_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 | Dataset Acquisition and Loading

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize

# Load the airbnb_df dataset from github
airbnb_df = pd.read_csv('https://raw.githubusercontent.com/Lechagria/dataset_lechagria/refs/heads/main/Airbnb_Broward.csv')

# %% [markdown]
# # 2 | Structural Investigation

# %%
airbnb_df.head()
# Out:
#        id                                               name  host_id  \
# 0   57818  50% OFF Monthly 32+days! Snowbird!  Walk to be...   275948
# 1   69824                          2 bd/2ba Oceanfront Condo   351303
# 2   83449           2 miles from the beach 2/1 sleeps 5 #204   454736
# 3  129099                MIAMI - AMAZING APARTMENT OCEANVIEW   637272
# 4  191160                 Tropical Beach Paradise Awaits You   924482
#
#                    host_name  neighbourhood_group     neighbourhood  latitude  \
# 0                    Von Inc                  NaN         Hollywood  26.01859
# 1                      Tracy                  NaN  Hallandale Beach  25.97641
# 2  Jon,  Mary Pop Apartments                  NaN       Dania Beach  26.03392
# 3                     Bianca                  NaN         Hollywood  25.99414
# 4                        Dan                  NaN   Deerfield Beach  26.30707
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -80.12430  Entire home/apt  250.0              31                 60
# 1  -80.12052  Entire home/apt  140.0              30                  4
# 2  -80.14201  Entire home/apt  130.0               7                 33
# 3  -80.11814  Entire home/apt  328.0              15                 28
# 4  -80.07793  Entire home/apt  119.0               2                 25
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2024-03-08               0.41                               2
# 1  2023-06-03               0.09                               2
# 2  2024-12-14               0.21                              16
# 3  2024-03-14               0.17                               5
# 4  2019-11-08               0.16                               1
#
#    availability_365  number_of_reviews_ltm license
# 0               305                      1     NaN
# 1               291                      0     NaN
# 2               127                      2     NaN
# 3               365                      1     NaN
# 4               118                      0     NaN

# %%
# we wanted to make sure that the 'id' column is a unique identifier. If the output is 'True', we'll keep it as is.
print(airbnb_df['id'].nunique() == len(airbnb_df))
# Out:
# True

# %%
print(airbnb_df.info())
print(airbnb_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17167 entries, 0 to 17166
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17167 non-null  int64
#  1   name                            17167 non-null  object
#  2   host_id                         17167 non-null  int64
#  3   host_name                       17166 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   17167 non-null  object
#  6   latitude                        17167 non-null  float64
#  7   longitude                       17167 non-null  float64
#  8   room_type                       17167 non-null  object
#  9   price                           15983 non-null  float64
#  10  minimum_nights                  17167 non-null  int64
#  11  number_of_reviews               17167 non-null  int64
#  12  last_review                     13940 non-null  object
#  13  reviews_per_month               13940 non-null  float64
#  14  calculated_host_listings_count  17167 non-null  int64
#  15  availability_365                17167 non-null  int64
#  16  number_of_reviews_ltm           17167 non-null  int64
#  17  license                         6 non-null      object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 2.4+ MB
# None
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.716700e+04  1.716700e+04                  0.0  17167.000000
# mean   6.521621e+17  2.332415e+08                  NaN     26.106091
# std    4.997975e+17  1.942118e+08                  NaN      0.099491
# min    5.781800e+04  5.146000e+03                  NaN     25.957017
# 25%    4.977412e+07  5.143385e+07                  NaN     26.007981
# 50%    7.885763e+17  1.747805e+08                  NaN     26.117990
# 75%    1.099933e+18  4.110870e+08                  NaN     26.178745
# max    1.319064e+18  6.680805e+08                  NaN     26.334900
#
#           longitude          price  minimum_nights  number_of_reviews  \
# count  17167.000000   15983.000000    17167.000000       17167.000000
# mean     -80.141398     361.404054        5.590319          34.560028
# std        0.051527    1059.830794       21.691480          64.566947
# min      -80.420633      10.000000        1.000000           0.000000
# 25%      -80.152374     129.000000        1.000000           1.000000
# 50%      -80.123370     207.000000        2.000000          11.000000
# 75%      -80.115539     385.000000        3.000000          41.000000
# max      -80.075314  100000.000000      999.000000        1833.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count       13940.000000                    17167.000000      17167.000000
# mean            1.439864                       25.307683        230.006874
# std             1.656405                       62.158937        115.499547
# min             0.010000                        1.000000          0.000000
# 25%             0.400000                        1.000000        136.000000
# 50%             1.000000                        5.000000        268.000000
# 75%             2.000000                       18.000000        332.000000
# max            50.500000                      384.000000        365.000000
#
#        number_of_reviews_ltm
# count           17167.000000
# mean               10.489194
# std                16.184196
# min                 0.000000
# 25%                 0.000000
# 50%                 4.000000
# 75%                15.000000
# max               408.000000

# %%
# updated column projection.
airbnb_df.head()
# Out:
#        id                                               name  host_id  \
# 0   57818  50% OFF Monthly 32+days! Snowbird!  Walk to be...   275948
# 1   69824                          2 bd/2ba Oceanfront Condo   351303
# 2   83449           2 miles from the beach 2/1 sleeps 5 #204   454736
# 3  129099                MIAMI - AMAZING APARTMENT OCEANVIEW   637272
# 4  191160                 Tropical Beach Paradise Awaits You   924482
#
#                    host_name  neighbourhood_group     neighbourhood  latitude  \
# 0                    Von Inc                  NaN         Hollywood  26.01859
# 1                      Tracy                  NaN  Hallandale Beach  25.97641
# 2  Jon,  Mary Pop Apartments                  NaN       Dania Beach  26.03392
# 3                     Bianca                  NaN         Hollywood  25.99414
# 4                        Dan                  NaN   Deerfield Beach  26.30707
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -80.12430  Entire home/apt  250.0              31                 60
# 1  -80.12052  Entire home/apt  140.0              30                  4
# 2  -80.14201  Entire home/apt  130.0               7                 33
# 3  -80.11814  Entire home/apt  328.0              15                 28
# 4  -80.07793  Entire home/apt  119.0               2                 25
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2024-03-08               0.41                               2
# 1  2023-06-03               0.09                               2
# 2  2024-12-14               0.21                              16
# 3  2024-03-14               0.17                               5
# 4  2019-11-08               0.16                               1
#
#    availability_365  number_of_reviews_ltm license
# 0               305                      1     NaN
# 1               291                      0     NaN
# 2               127                      2     NaN
# 3               365                      1     NaN
# 4               118                      0     NaN

# %% [markdown]
# # 3  | Quality Investigation

# %% [markdown]
# ##Dropping columns

# %%
#neighbourhood_group column is empty - so is better to drop it.
airbnb_df = airbnb_df.drop('neighbourhood_group', axis=1)

#license column only has 6 rows let's drop it also
airbnb_df = airbnb_df.drop('license', axis=1)

# %% [markdown]
# ##Handling Nulls
# (And creating one new column)

# %%
#Calculate the mean of 'last_review' (excluding NaT values)
mean_last_review = airbnb_df['last_review'].mean()

#Fill NaN values in 'last_review' with the mean using direct assignment
airbnb_df['last_review'] = airbnb_df['last_review'].fillna(mean_last_review)

#Calculate the mode of 'reviews_per_month'
mode_reviews_per_month = airbnb_df['reviews_per_month'].mode()[0]

#Fill NaN values in 'reviews_per_month' with the mode using direct assignment
airbnb_df['reviews_per_month'] = airbnb_df['reviews_per_month'].fillna(mode_reviews_per_month)

#There is a single null in the host_name column, let's just fill it with a random value "Dixie"
airbnb_df['host_name'] = airbnb_df['host_name'].fillna("Dixie")

#Group by 'neighbourhood' and calculate the mean 'price' for each group
neighborhood_mean_prices = airbnb_df.groupby('neighbourhood')['price'].mean()

#Create a new column to store the mean price, by neighbourhood
airbnb_df['neighborhood_mean_price'] = airbnb_df['neighbourhood'].map(neighborhood_mean_prices)

#Fill NaN values in 'price' with the corresponding 'neighborhood_mean_price'
airbnb_df['price'] = airbnb_df['price'].fillna(airbnb_df['neighborhood_mean_price'])

# %% [markdown]
# ##Fixing data types

# %%
# Convert 'last_review' column to datetime objects
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'])

# %% [markdown]
# ##Identifying and Treating Outliers in the 'Price' Column

# %%
#What prices are in what percentiles

percentiles = [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
percentile_values = airbnb_df['price'].quantile(q=[p/100 for p in percentiles])

#Create a DataFrame to display the percentiles and their corresponding price values
percentile_df = pd.DataFrame({'Percentile': percentiles, 'Price': percentile_values})

percentile_df
# Out:
#       Percentile    Price
# 0.90          90   653.00
# 0.91          91   693.00
# 0.92          92   745.00
# 0.93          93   800.00
# 0.94          94   867.04
# 0.95          95   950.70
# 0.96          96  1034.36
# 0.97          97  1217.02
# 0.98          98  1509.40
# 0.99          99  2202.74

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17167 entries, 0 to 17166
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17167 non-null  int64
#  1   name                            17167 non-null  object
#  2   host_id                         17167 non-null  int64
#  3   host_name                       17167 non-null  object
#  4   neighbourhood                   17167 non-null  object
#  5   latitude                        17167 non-null  float64
#  6   longitude                       17167 non-null  float64
#  7   room_type                       17167 non-null  object
#  8   price                           17167 non-null  float64
#  9   minimum_nights                  17167 non-null  int64
#  10  number_of_reviews               17167 non-null  int64
#  11  last_review                     17167 non-null  datetime64[ns]
#  12  reviews_per_month               17167 non-null  float64
#  13  calculated_host_listings_count  17167 non-null  int64
#  14  availability_365                17167 non-null  int64
#  15  number_of_reviews_ltm           17167 non-null  int64
#  16  neighborhood_mean_price         17167 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(7), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# # 4 | Data Integration

# %% [markdown]
# # 5 | Data Binning

# %%
bins = [0, 30, 90, 180, 365]
labels = ['Rarely Available', 'Seasonal', 'Half-Year', 'Year-Round']
airbnb_df['availability_cat'] = pd.cut(airbnb_df['availability_365'], bins=bins, labels=labels)
airbnb_df.head()
# Out:
#        id                                               name  host_id  \
# 0   57818  50% OFF Monthly 32+days! Snowbird!  Walk to be...   275948
# 1   69824                          2 bd/2ba Oceanfront Condo   351303
# 2   83449           2 miles from the beach 2/1 sleeps 5 #204   454736
# 3  129099                MIAMI - AMAZING APARTMENT OCEANVIEW   637272
# 4  191160                 Tropical Beach Paradise Awaits You   924482
#
#                    host_name     neighbourhood  latitude  longitude  \
# 0                    Von Inc         Hollywood  26.01859  -80.12430
# 1                      Tracy  Hallandale Beach  25.97641  -80.12052
# 2  Jon,  Mary Pop Apartments       Dania Beach  26.03392  -80.14201
# 3                     Bianca         Hollywood  25.99414  -80.11814
# 4                        Dan   Deerfield Beach  26.30707  -80.07793
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt  250.0              31                 60  2024-03-08
# 1  Entire home/apt  140.0              30                  4  2023-06-03
# 2  Entire home/apt  130.0               7                 33  2024-12-14
# 3  Entire home/apt  328.0              15                 28  2024-03-14
# 4  Entire home/apt  119.0               2                 25  2019-11-08
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.41                               2               305
# 1               0.09                               2               291
# 2               0.21                              16               127
# 3               0.17                               5               365
# 4               0.16                               1               118
#
#    number_of_reviews_ltm license availability_cat
# 0                      1     NaN       Year-Round
# 1                      0     NaN       Year-Round
# 2                      2     NaN        Half-Year
# 3                      1     NaN       Year-Round
# 4                      0     NaN        Half-Year

# %% [markdown]
# # 6 | LAMBDA Function

# %%
airbnb_df['price_category'] = airbnb_df['price'].apply(lambda x: 'Low' if x < 100 else ('Mid' if x < 250 else 'High'))

# %%
airbnb_df.head()
# Out:
#        id                                               name  host_id  \
# 0   57818  50% OFF Monthly 32+days! Snowbird!  Walk to be...   275948
# 1   69824                          2 bd/2ba Oceanfront Condo   351303
# 2   83449           2 miles from the beach 2/1 sleeps 5 #204   454736
# 3  129099                MIAMI - AMAZING APARTMENT OCEANVIEW   637272
# 4  191160                 Tropical Beach Paradise Awaits You   924482
#
#                    host_name     neighbourhood  latitude  longitude  \
# 0                    Von Inc         Hollywood  26.01859  -80.12430
# 1                      Tracy  Hallandale Beach  25.97641  -80.12052
# 2  Jon,  Mary Pop Apartments       Dania Beach  26.03392  -80.14201
# 3                     Bianca         Hollywood  25.99414  -80.11814
# 4                        Dan   Deerfield Beach  26.30707  -80.07793
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt  250.0              31                 60  2024-03-08
# 1  Entire home/apt  140.0              30                  4  2023-06-03
# 2  Entire home/apt  130.0               7                 33  2024-12-14
# 3  Entire home/apt  328.0              15                 28  2024-03-14
# 4  Entire home/apt  119.0               2                 25  2019-11-08
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.41                               2               305
# 1               0.09                               2               291
# 2               0.21                              16               127
# 3               0.17                               5               365
# 4               0.16                               1               118
#
#    number_of_reviews_ltm license availability_cat price_category
# 0                      1     NaN       Year-Round           High
# 1                      0     NaN       Year-Round            Mid
# 2                      2     NaN        Half-Year            Mid
# 3                      1     NaN       Year-Round           High
# 4                      0     NaN        Half-Year            Mid

# %% [markdown]
# # 7 | Feature Engineering

# %%
from datetime import datetime

airbnb_df['last_review_days_ago'] = (datetime.now() - pd.to_datetime(airbnb_df['last_review'])).dt.days

airbnb_df.head()
# Out:
#        id                                               name  host_id  \
# 0   57818  50% OFF Monthly 32+days! Snowbird!  Walk to be...   275948
# 1   69824                          2 bd/2ba Oceanfront Condo   351303
# 2   83449           2 miles from the beach 2/1 sleeps 5 #204   454736
# 3  129099                MIAMI - AMAZING APARTMENT OCEANVIEW   637272
# 4  191160                 Tropical Beach Paradise Awaits You   924482
#
#                    host_name     neighbourhood  latitude  longitude  \
# 0                    Von Inc         Hollywood  26.01859  -80.12430
# 1                      Tracy  Hallandale Beach  25.97641  -80.12052
# 2  Jon,  Mary Pop Apartments       Dania Beach  26.03392  -80.14201
# 3                     Bianca         Hollywood  25.99414  -80.11814
# 4                        Dan   Deerfield Beach  26.30707  -80.07793
#
#          room_type  price  minimum_nights  ...  last_review reviews_per_month  \
# 0  Entire home/apt  250.0              31  ...   2024-03-08              0.41
# 1  Entire home/apt  140.0              30  ...   2023-06-03              0.09
# 2  Entire home/apt  130.0               7  ...   2024-12-14              0.21
# 3  Entire home/apt  328.0              15  ...   2024-03-14              0.17
# 4  Entire home/apt  119.0               2  ...   2019-11-08              0.16
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               2               305                      1
# 1                               2               291                      0
# 2                              16               127                      2
# 3                               5               365                      1
# 4                               1               118                      0
#
#    license availability_cat price_category popularity_score  \
# 0      NaN       Year-Round           High           125.05
# 1      NaN       Year-Round            Mid            26.19
# 2      NaN        Half-Year            Mid            26.67
# 3      NaN       Year-Round           High            62.05
# 4      NaN        Half-Year            Mid            18.88
#
#    last_review_days_ago
# 0                 351.0
# 1                 630.0
# 2                  70.0
# 3                 345.0
# 4                1933.0
#
# [5 rows x 21 columns]
